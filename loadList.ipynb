# %%
import pandas as pd

# %%
df = pd.read_csv('src/pokemon.csv')

# %%
its = (df['Type 1'] == 'Fire') | (df['Type 2'] == 'Fire')

# %%
data = df.loc[(its), ['Name', 'Attack', 'Defense']]

# %%
display(data.head(10))
# Out:
#                          Name  Attack  Defense
# 4                  Charmander      52       43
# 5                  Charmeleon      64       58
# 6                   Charizard      84       78
# 7   CharizardMega Charizard X     130      111
# 8   CharizardMega Charizard Y     104       78
# 42                     Vulpix      41       40
# 43                  Ninetales      76       75
# 63                  Growlithe      70       45
# 64                   Arcanine     110       80
# 83                     Ponyta      85       55
